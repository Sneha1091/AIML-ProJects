# %% [markdown]
# # Importing libraries and data set

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
colnames = ['User_Id', 'Prod_Id', 'Rating', 'Time_Stamp']

df = pd.read_csv("ratings_Electronics.csv", names= colnames)

df.head()
# Out:
#           User_Id     Prod_Id  Rating  Time_Stamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200

# %%
df.tail()
# Out:
#                 User_Id     Prod_Id  Rating  Time_Stamp
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0  1396569600
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0  1313366400
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0  1404172800
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0  1297555200
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0  1312675200

# %%
df.shape
# Out:
# (7824482, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824482 entries, 0 to 7824481
# Data columns (total 4 columns):
# User_Id       object
# Prod_Id       object
# Rating        float64
# Time_Stamp    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 238.8+ MB

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Creating a subset of the actual data set

# %%
#Dropping the users who have given less than 50 ratings
df1 = df[df['User_Id'].isin(df['User_Id'].value_counts()[df['User_Id'].value_counts()>50].index)]

# %%
df1.shape
# Out:
# (122171, 4)

# %% [raw]
# sns.pairplot(df1)

# %%
#Converting User Id and Product Id columns into categorical for easier calculations

for col_name in df1.columns:
    if(df1[col_name].dtype == 'object'):
        df1[col_name]= df1[col_name].astype('category')
        df1[col_name] = df1[col_name].cat.codes

df1.head()
# Out:
#      User_Id  Prod_Id  Rating  Time_Stamp
# 118     1390        0     3.0  1377907200
# 177      806        1     1.0  1319673600
# 178       79        1     4.0  1281744000
# 492      902        2     5.0  1373587200
# 631     1089        2     5.0  1353456000

# %%
#Dropping Time Stamp column

df1 = df1.drop('Time_Stamp', axis = 1)

# %% [markdown]
# # Building a Popularity model

# %%
df1.groupby('Prod_Id')['Rating'].mean().head()
# Out:
# Prod_Id
# 0    3.0
# 1    2.5
# 2    5.0
# 3    3.0
# 4    5.0
# Name: Rating, dtype: float64

# %%
df1.groupby('Prod_Id')['Rating'].mean().sort_values(ascending=False).head()
# Out:
# Prod_Id
# 47154    5.0
# 9294     5.0
# 9306     5.0
# 28351    5.0
# 28352    5.0
# Name: Rating, dtype: float64

# %%
df1.groupby('Prod_Id')['Rating'].count().sort_values(ascending=False).head()
# Out:
# Prod_Id
# 38146    204
# 24262    177
# 10820    163
# 37407    156
# 37765    146
# Name: Rating, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(df1.groupby('Prod_Id')['Rating'].mean())

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(df1.groupby('Prod_Id')['Rating'].count())

# %%
#Showing 5 most rated products(they are not highly rated but they are rated most number of times and have not full but very high ratings)
ratings_mean_count.sort_values(['rating_counts'], ascending = False).head()
# Out:
#            Rating  rating_counts
# Prod_Id
# 38146    4.215686            204
# 24262    4.858757            177
# 10820    4.773006            163
# 37407    4.692308            156
# 37765    4.431507            146

# %% [raw]
# ratings_mean_count['rating_counts'].sort_values(ascending=False)
# ratings_mean_count.head()

# %% [markdown]
# # Building a Collaborative Filtering model using SVD

# %%
from collections import defaultdict
from surprise import SVD
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
reader = Reader(rating_scale = (1, 5))

# %%
#Creating data set using above "train set which is 70% of original data
data = Dataset.load_from_df(df1, reader)

# %%
#Splitting the data
trainset, testset = train_test_split(data, test_size = 0.3, random_state = 123)

# %%
algo = SVD(n_factors = 50)

# %%
algo.fit(trainset)

# %%
predictions = algo.test(testset)

# %%
p = pd.DataFrame(predictions)

# %%
p.shape
# Out:
# (36652, 5)

# %%
p
# Out:
#         uid    iid  r_ui       est                    details
# 0       625  20804   5.0  4.739962  {'was_impossible': False}
# 1       605  26949   5.0  4.877509  {'was_impossible': False}
# 2      1342   5211   5.0  4.645265  {'was_impossible': False}
# 3       367  37888   4.0  4.282892  {'was_impossible': False}
# 4       378  40116   4.0  4.875615  {'was_impossible': False}
# 5      1302  44216   4.0  4.598920  {'was_impossible': False}
# 6      1357  34277   4.0  4.417519  {'was_impossible': False}
# 7       432   2410   1.0  4.472193  {'was_impossible': False}
# 8       374  10509   5.0  3.858597  {'was_impossible': False}
# 9       162  28799   3.0  4.331866  {'was_impossible': False}
# 10      226   8487   5.0  4.210557  {'was_impossible': False}
# 11      288  32610   4.0  4.301835  {'was_impossible': False}
# 12      360  35358   5.0  4.378707  {'was_impossible': False}
# 13      849  28941   5.0  4.597158  {'was_impossible': False}
# 14      189  42824   3.0  3.897222  {'was_impossible': False}
# 15     1156  43849   4.0  4.680306  {'was_impossible': False}
# 16      327  39210   2.0  4.164541  {'was_impossible': False}
# 17      589  11685   5.0  4.483612  {'was_impossible': False}
# 18     1113  36035   5.0  4.563907  {'was_impossible': False}
# 19      163  16297   1.0  4.063702  {'was_impossible': False}
# 20      503  40131   4.0  5.000000  {'was_impossible': False}
# 21     1376  16966   1.0  3.472193  {'was_impossible': False}
# 22      559  44927   4.0  4.170608  {'was_impossible': False}
# 23      845  27985   3.0  3.788957  {'was_impossible': False}
# 24      557  14946   5.0  3.931256  {'was_impossible': False}
# 25      759  14045   1.0  2.524063  {'was_impossible': False}
# 26      107  16930   4.0  4.228238  {'was_impossible': False}
# 27      385  24751   3.0  4.073894  {'was_impossible': False}
# 28      700   7827   5.0  4.058556  {'was_impossible': False}
# 29     1285  44367   4.0  4.567917  {'was_impossible': False}
# ...     ...    ...   ...       ...                        ...
# 36622  1133  45350   4.0  4.184346  {'was_impossible': False}
# 36623   462  30969   3.0  4.083726  {'was_impossible': False}
# 36624  1033  34399   3.0  4.471498  {'was_impossible': False}
# 36625  1047   7650   5.0  4.451139  {'was_impossible': False}
# 36626   881  39081   5.0  4.604729  {'was_impossible': False}
# 36627   816  29242   5.0  3.697804  {'was_impossible': False}
# 36628  1072  16727   5.0  4.459824  {'was_impossible': False}
# 36629    67   9052   5.0  4.877828  {'was_impossible': False}
# 36630   409  40707   5.0  4.538622  {'was_impossible': False}
# 36631  1047  28106   5.0  4.310321  {'was_impossible': False}
# 36632   825  46779   3.0  4.549750  {'was_impossible': False}
# 36633   347  16013   5.0  4.617634  {'was_impossible': False}
# 36634   674  30135   3.0  4.603746  {'was_impossible': False}
# 36635   503  46124   4.0  4.650236  {'was_impossible': False}
# 36636  1339  46122   4.0  4.264652  {'was_impossible': False}
# 36637   523  11588   5.0  4.395054  {'was_impossible': False}
# 36638  1136  24262   5.0  4.793794  {'was_impossible': False}
# 36639   364  28102   5.0  4.570567  {'was_impossible': False}
# 36640  1021  11127   5.0  4.490961  {'was_impossible': False}
# 36641  1001  36681   4.0  4.073233  {'was_impossible': False}
# 36642  1123  20861   3.0  3.771406  {'was_impossible': False}
# 36643   800  30900   5.0  4.459594  {'was_impossible': False}
# 36644  1168   7866   5.0  4.748361  {'was_impossible': False}
# 36645   554  27091   4.0  4.452951  {'was_impossible': False}
# 36646  1068  46436   4.0  4.173698  {'was_impossible': False}
# 36647  1140  26461   5.0  4.842108  {'was_impossible': False}
# 36648   284   9046   5.0  4.875261  {'was_impossible': False}
# 36649   441  13621   5.0  5.000000  {'was_impossible': False}
# 36650  1353   8020   5.0  4.264243  {'was_impossible': False}
# 36651   703  45883   4.0  4.345641  {'was_impossible': False}
#
# [36652 rows x 5 columns]

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9832
# 0.9831804028583833

# %%
p.sort_values(['est'], ascending = False)
# Out:
#         uid    iid  r_ui       est                    details
# 21689   271  34383   5.0  5.000000  {'was_impossible': False}
# 6570   1296  42630   5.0  5.000000  {'was_impossible': False}
# 12734   869  27768   4.0  5.000000  {'was_impossible': False}
# 483    1019  37407   5.0  5.000000  {'was_impossible': False}
# 9143    150  18458   5.0  5.000000  {'was_impossible': False}
# 5964    906  30375   5.0  5.000000  {'was_impossible': False}
# 3308    795  43315   5.0  5.000000  {'was_impossible': False}
# 5156    570  34519   5.0  5.000000  {'was_impossible': False}
# 33373  1333  42631   5.0  5.000000  {'was_impossible': False}
# 17287   262   4170   5.0  5.000000  {'was_impossible': False}
# 19477   463  31430   5.0  5.000000  {'was_impossible': False}
# 6583   1118  24262   5.0  5.000000  {'was_impossible': False}
# 34228   915  40003   5.0  5.000000  {'was_impossible': False}
# 30359    11  45310   5.0  5.000000  {'was_impossible': False}
# 35862   717  17518   5.0  5.000000  {'was_impossible': False}
# 3046    418  42650   5.0  5.000000  {'was_impossible': False}
# 12726   605  40817   5.0  5.000000  {'was_impossible': False}
# 498     809  24262   5.0  5.000000  {'was_impossible': False}
# 28930   992  35799   5.0  5.000000  {'was_impossible': False}
# 34225   206  23182   5.0  5.000000  {'was_impossible': False}
# 3808    463  29879   5.0  5.000000  {'was_impossible': False}
# 1998    752  20568   5.0  5.000000  {'was_impossible': False}
# 35892   113  37763   5.0  5.000000  {'was_impossible': False}
# 28956   738  24262   4.0  5.000000  {'was_impossible': False}
# 28998   441  39856   5.0  5.000000  {'was_impossible': False}
# 21652   346  46690   5.0  5.000000  {'was_impossible': False}
# 15722  1134  15697   5.0  5.000000  {'was_impossible': False}
# 33338  1428  13402   5.0  5.000000  {'was_impossible': False}
# 11760  1102  25729   5.0  5.000000  {'was_impossible': False}
# 5939    587  18690   5.0  5.000000  {'was_impossible': False}
# ...     ...    ...   ...       ...                        ...
# 16816   386  12309   1.0  2.427050  {'was_impossible': False}
# 1613   1409   8321   1.0  2.405226  {'was_impossible': False}
# 12003   386  16433   1.0  2.397424  {'was_impossible': False}
# 21523  1409  11402   1.0  2.397096  {'was_impossible': False}
# 19594   626  21117   2.0  2.387575  {'was_impossible': False}
# 14445   759  40097   3.0  2.378771  {'was_impossible': False}
# 1366    759   9622   2.0  2.362194  {'was_impossible': False}
# 19213   386  16290   1.0  2.336054  {'was_impossible': False}
# 33180   308  29317   1.0  2.332911  {'was_impossible': False}
# 5613    386  12588   1.0  2.322540  {'was_impossible': False}
# 12120   104  44906   4.0  2.303939  {'was_impossible': False}
# 558     386  15596   5.0  2.303293  {'was_impossible': False}
# 21224   386  26728   3.0  2.302024  {'was_impossible': False}
# 14772   386  20572   5.0  2.298510  {'was_impossible': False}
# 8713    386  16235   5.0  2.279744  {'was_impossible': False}
# 20186   308   8379   3.0  2.251535  {'was_impossible': False}
# 21267   759   8421   1.0  2.198469  {'was_impossible': False}
# 23024  1409  21027   2.0  2.190084  {'was_impossible': False}
# 35525   759   1263   5.0  2.183737  {'was_impossible': False}
# 18910   626  14733   2.0  2.121172  {'was_impossible': False}
# 6778    522  19498   2.0  2.112197  {'was_impossible': False}
# 27321   386  15714   5.0  2.085038  {'was_impossible': False}
# 2574    386  15530   5.0  2.078890  {'was_impossible': False}
# 28696   562  25195   1.0  2.049800  {'was_impossible': False}
# 21192   104  43034   1.0  1.981083  {'was_impossible': False}
# 5425    386  12313   5.0  1.964521  {'was_impossible': False}
# 30530  1171  31635   1.0  1.853352  {'was_impossible': False}
# 23565   386   2454   1.0  1.841061  {'was_impossible': False}
# 31329   386  13357   2.0  1.782233  {'was_impossible': False}
# 15654   386  13586   1.0  1.687137  {'was_impossible': False}
#
# [36652 rows x 5 columns]

# %%
#Function to find top 5 recommendation for anyone of the user
def get_top_n(predictions, n=5):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
top_n = get_top_n(predictions, n=5)

# %%
#Getting top ten recommendations for user '558'
top = pd.DataFrame(top_n.get(558))

# %%
top.columns = ['Prod_Id', 'Ratings']

# %%
#Showing the name of the top ten books for user '558'
top.head(10)
# Out:
#    Prod_Id   Ratings
# 0    24262  5.000000
# 1    43790  4.999813
# 2    22989  4.877099
# 3    34503  4.625899
# 4    44998  4.599102
