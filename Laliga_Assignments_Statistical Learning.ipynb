# %%
import numpy as np
import pandas as pd

# %%
Laliga=pd.read_csv('Laliga.csv',header=1,na_values='-')
Laliga.head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0      563.0    5947.0        3140.0      33.0       23.0    8.0     8.0
# 1      608.0    5900.0        3114.0      25.0       25.0   12.0    12.0
# 2      775.0    4534.0        3309.0      10.0        8.0   16.0     9.0
# 3      861.0    4398.0        3469.0       6.0        6.0   10.0    11.0
# 4      920.0    4631.0        3700.0       8.0        7.0   10.0     5.0
#
#    Fifth  Sixth     T    Debut Since/LastApp  BestPosition
# ...

# %% [markdown]
# Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)

# %%
Laliga=Laliga.replace('-',0)
Laliga
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %% [markdown]
# Print all the teams which have started playing between 1930-1980. (5 points)

# %%
Laliga[(Laliga['Debut']>'1930') & (Laliga['Debut']<'1980')]
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3     4             Valencia       82   3386        2664     1187        616
# 5     6              Sevilla       73   2819        2408      990        531
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# 11   12           Celta Vigo       51   1789        1698      586        389
# 12   13           Valladolid       42   1471        1466      463        384
# 14   15       Sporting Gijon       43   1389        1458      471        358
# 15   16              Osasuna       37   1351        1318      426        327
# 16   17               Malaga       36   1314        1255      390        330
# 17   18               Oviedo       38   1174        1192      408        292
# ...

# %%
Laliga_team=Laliga[(Laliga['Debut']>'1930') & (Laliga['Debut']<'1980')]
Laliga_team['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %% [markdown]
# 3.Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
#Laliga.describe().nlargest(5, Champion)
Laliga.Champion=Laliga.Champion.astype('int64') 

Laliga_Top_Team=Laliga.nlargest(5, 'Champion')
Laliga_Top_Team['Team']
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 4    Athletic Bilbao
# 3           Valencia
# Name: Team, dtype: object

# %% [markdown]
# 4.Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
# Goal_diff_count = GoalsFor - GoalsAgainst

# %%
def Goal_diff(Team,GoalsFor,GoalsAgainst):
    diff=GoalsFor-GoalsAgainst
    Max=pd.DataFrame({'Team':Team[GoalsFor-GoalsAgainst==diff.max()],'diff':diff.max()})
    Min=pd.DataFrame({'Team':Team[GoalsFor-GoalsAgainst==diff.min()],'diff':diff.min()})
    f=[Max,Min]
    return pd.concat(f)
Goal_diff(Laliga.Team,Laliga.GoalsFor,Laliga.GoalsAgainst)
# Out:
#                 Team    diff
# 0        Real Madrid  2807.0
# 13  Racing Santander  -525.0

# %% [markdown]
# 5 Create a new column with name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100
#
# If there are any numerical error, replace it with 0%
#
# Print the top 5 teams which has the highest Winning percentage

# %%
Laliga.GamesWon=Laliga.GamesWon.astype('int64') 
Laliga.GamesPlayed=Laliga.GamesPlayed.astype('int64') 
Laliga['Winning Percent']=(Laliga['GamesWon']/Laliga['GamesPlayed'])*100
pd.DataFrame({'Team':Laliga.nlargest(5,'Winning Percent')['Team'],'Winning Percent':Laliga.nlargest(5,'Winning Percent')['Winning Percent']})
# Out:
#               Team  Winning Percent
# 0      Real Madrid        59.630702
# 1        Barcelona        57.241130
# 2  Atletico Madrid        47.475134
# 3         Valencia        44.557057
# 4  Athletic Bilbao        43.772629

# %% [markdown]
# 6.Group teams based on their “Best position” and print the sum of their points for all positions (5 points)
# Eg: Best Position                Points
#
#         1                              25000
#
#         2                              7000

# %%
Laliga_new=['BestPosition','Points']
Laliga_new['BestPosition','Points']=Laliga['BestPosition']
Laliga_new
# Out:
# ['BestPosition', 'Points']

# %%
pd.DataFrame({'Points':Laliga.groupby('BestPosition')['Points'].sum()})
# Out:
#                Points
# BestPosition
# 1             27933.0
# 2              6904.0
# 3              5221.0
# 4              6563.0
# 5              1884.0
# 6              2113.0
# 7              1186.0
# 8              1134.0
# 9                96.0
# 10              450.0
# 11              445.0
# 12              511.0
# 14               71.0
# 15               14.0
# 16               81.0
# 17              266.0
# 19               81.0
# 20               34.0
